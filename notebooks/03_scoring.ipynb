# %%
import pandas as pd
import numpy as np
import joblib
from march_madness.config import PROCESSED_DATA_DIR, MODELS_DIR

# %%
model_load = joblib.load(MODELS_DIR / 'grid_search.pkl')
model = model_load.best_estimator_

# %%
features = list(model.feature_names_in_)

# %%
df_reg_final = pd.read_parquet(PROCESSED_DATA_DIR / 'df_reg_final.parquet')
df_seeds = pd.read_parquet(PROCESSED_DATA_DIR / 'df_seeds.parquet')
